# %%
import pypdb

# %%
all_info = pypdb.get_all_info('1a0l')

# %%
from pprint import pprint

# %%
pprint(all_info)
# Out:
# {'audit_author': [{'name': 'Pereira, P.J.B.', 'pdbx_ordinal': 1},
#                   {'name': 'Bergner, A.', 'pdbx_ordinal': 2},
#                   {'name': 'Macedo-Ribeiro, S.', 'pdbx_ordinal': 3},
#                   {'name': 'Huber, R.', 'pdbx_ordinal': 4},
#                   {'name': 'Matschiner, G.', 'pdbx_ordinal': 5},
#                   {'name': 'Fritz, H.', 'pdbx_ordinal': 6},
#                   {'name': 'Sommerhoff, C.P.', 'pdbx_ordinal': 7},
#                   {'name': 'Bode, W.', 'pdbx_ordinal': 8}],
#  'cell': {'angle_alpha': 90.0,
#           'angle_beta': 90.0,
#           'angle_gamma': 90.0,
#           'length_a': 82.93,
#           'length_b': 82.93,
#           'length_c': 172.86,
#           'zpdb': 16},
#  'citation': [{'country': 'UK',
#                'id': 'primary',
#                'journal_abbrev': 'Nature',
#                'journal_id_astm': 'NATUAS',
#                'journal_id_csd': '0006',
#                'journal_id_issn': '0028-0836',
#                'journal_volume': '392',
#                'page_first': '306',
#                'page_last': '311',
#                'pdbx_database_id_doi': '10.1038/32703',
#                'pdbx_database_id_pub_med': 9521329,
#                'rcsb_authors': ['Pereira, P.J.',
#                                 'Bergner, A.',
#                                 'Macedo-Ribeiro, S.',
#                                 'Huber, R.',
#                                 'Matschiner, G.',
#                                 'Fritz, H.',
#                                 'Sommerhoff, C.P.',
#                                 'Bode, W.'],
#                'rcsb_is_primary': 'Y',
#                'rcsb_journal_abbrev': 'Nature',
#                'title': 'Human beta-tryptase is a ring-like tetramer with '
#                         'active sites facing a central pore.',
#                'year': 1998}],
#  'diffrn': [{'ambient_temp': 283.0, 'crystal_id': '1', 'id': '1'}],
#  'diffrn_detector': [{'detector': 'IMAGE PLATE',
#                       'diffrn_id': '1',
#                       'pdbx_collection_date': '1997-02-07T00:00:00+0000',
#                       'type': 'MARRESEARCH'}],
#  'diffrn_radiation': [{'diffrn_id': '1',
#                        'monochromator': 'GRAPHITE(002)',
#                        'pdbx_monochromatic_or_laue_ml': 'M',
#                        'pdbx_scattering_type': 'x-ray',
#                        'wavelength_id': '1'}],
#  'diffrn_source': [{'diffrn_id': '1',
#                     'pdbx_wavelength': '1.5418',
#                     'source': 'ROTATING ANODE',
#                     'type': 'RIGAKU RUH2R'}],
#  'entry': {'id': '1A0L'},
#  'exptl': [{'crystals_number': 1, 'method': 'X-RAY DIFFRACTION'}],
#  'exptl_crystal': [{'density_matthews': 2.48,
#                     'density_percent_sol': 50.0,
#                     'id': '1'}],
#  'exptl_crystal_grow': [{'crystal_id': '1',
#                          'p_h': 5.0,
#                          'pdbx_details': 'pH 5.0'}],
#  'pdbx_audit_revision_details': [{'data_content_type': 'Structure model',
#                                   'ordinal': 1,
#                                   'provider': 'repository',
#                                   'revision_ordinal': 1,
#                                   'type': 'Initial release'}],
#  'pdbx_audit_revision_group': [{'data_content_type': 'Structure model',
#                                 'group': 'Version format compliance',
#                                 'ordinal': 1,
#                                 'revision_ordinal': 2},
#                                {'data_content_type': 'Structure model',
#                                 'group': 'Non-polymer description',
#                                 'ordinal': 2,
#                                 'revision_ordinal': 3},
#                                {'data_content_type': 'Structure model',
#                                 'group': 'Version format compliance',
#                                 'ordinal': 3,
#                                 'revision_ordinal': 3}],
#  'pdbx_audit_revision_history': [{'data_content_type': 'Structure model',
#                                   'major_revision': 1,
#                                   'minor_revision': 0,
#                                   'ordinal': 1,
#                                   'revision_date': '1999-03-23T00:00:00+0000'},
#                                  {'data_content_type': 'Structure model',
#                                   'major_revision': 1,
#                                   'minor_revision': 1,
#                                   'ordinal': 2,
#                                   'revision_date': '2008-03-24T00:00:00+0000'},
#                                  {'data_content_type': 'Structure model',
#                                   'major_revision': 1,
#                                   'minor_revision': 2,
#                                   'ordinal': 3,
#                                   'revision_date': '2011-07-13T00:00:00+0000'}],
#  'pdbx_database_status': {'pdb_format_compatible': 'Y',
#                           'process_site': 'BNL',
#                           'recvd_initial_deposition_date': '1997-12-03T00:00:00+0000',
#                           'status_code': 'REL'},
#  'pdbx_vrpt_summary': {'absolute_percentile_clashscore': 17.7,
#                        'absolute_percentile_percent_ramachandran_outliers': 17.2,
#                        'absolute_percentile_percent_rotamer_outliers': 26.0,
#                        'angles_rmsz': 0.73,
#                        'attempted_validation_steps': 'molprobity,validation-pack,mogul,buster-report,percentiles,writexml',
#                        'bonds_rmsz': 0.48,
#                        'clashscore': 13.55,
#                        'high_resol_relative_percentile_clashscore': 3.0,
#                        'high_resol_relative_percentile_percent_ramachandran_outliers': 3.0,
#                        'high_resol_relative_percentile_percent_rotamer_outliers': 3.0,
#                        'low_resol_relative_percentile_clashscore': 3.0,
#                        'low_resol_relative_percentile_percent_ramachandran_outliers': 3.0,
#                        'low_resol_relative_percentile_percent_rotamer_outliers': 3.0,
#                        'no_ligands_for_buster_report': 'yes',
#                        'num_angles_rmsz': 10924,
#                        'num_bonds_rmsz': 7976,
#                        'num_hreduce': 7504.0,
#                        'num_pdbids_absolute_percentile_clashscore': 141614,
#                        'num_pdbids_absolute_percentile_percent_ramachandran_outliers': 138981,
#                        'num_pdbids_absolute_percentile_percent_rotamer_outliers': 138945,
#                        'num_pdbids_relative_percentile_clashscore': 2416,
#                        'num_pdbids_relative_percentile_percent_ramachandran_outliers': 2333,
#                        'num_pdbids_relative_percentile_percent_rotamer_outliers': 2336,
#                        'pdb_r': 0.2,
#                        'pdbdeposition_date': '1997-12-03T00:00:00+0000',
#                        'pdbresolution': 3.0,
#                        'pdbresolution_low': 10.0,
#                        'pdbrevision_date': '2011-07-13T00:00:00+0000',
#                        'pdbrevision_number': 3.0,
#                        'pdbrfree': 0.28,
#                        'percent_ramachandran_outliers': 0.93,
#                        'percent_rotamer_outliers': 4.67,
#                        'percentilebins': ['all', '3.0', 'xray'],
#                        'protein_dnarnaentities': '1',
#                        'relative_percentile_clashscore': 52.6,
#                        'relative_percentile_percent_ramachandran_outliers': 55.4,
#                        'relative_percentile_percent_rotamer_outliers': 62.9,
#                        'report_creation_date': 'May 16, 2020 -- 08:29 pm BST',
#                        'restypes_notchecked_for_bond_angle_geometry': ['APA']},
#  'rcsb_accession_info': {'deposit_date': '1997-12-03T00:00:00+0000',
#                          'has_released_experimental_data': 'N',
#                          'initial_release_date': '1999-03-23T00:00:00+0000',
#                          'major_revision': 1,
#                          'minor_revision': 2,
#                          'revision_date': '2011-07-13T00:00:00+0000',
#                          'status_code': 'REL'},
#  'rcsb_entry_container_identifiers': {'assembly_ids': ['1'],
#                                       'entity_ids': ['1', '2', '3'],
#                                       'entry_id': '1A0L',
#                                       'model_ids': [1],
#                                       'non_polymer_entity_ids': ['2'],
#                                       'polymer_entity_ids': ['1'],
#                                       'pubmed_id': 9521329,
#                                       'rcsb_id': '1A0L'},
#  'rcsb_entry_info': {'assembly_count': 1,
#                      'branched_entity_count': 0,
#                      'cis_peptide_count': 8,
#                      'deposited_atom_count': 7872,
#                      'deposited_hydrogen_atom_count': 0,
#                      'deposited_model_count': 1,
#                      'deposited_modeled_polymer_monomer_count': 976,
#                      'deposited_nonpolymer_entity_instance_count': 4,
#                      'deposited_polymer_entity_instance_count': 4,
#                      'deposited_polymer_monomer_count': 976,
#                      'deposited_solvent_atom_count': 96,
#                      'deposited_unmodeled_polymer_monomer_count': 0,
#                      'diffrn_radiation_wavelength_maximum': 1.5418,
#                      'diffrn_radiation_wavelength_minimum': 1.5418,
#                      'diffrn_resolution_high': {'provenance_source': 'Depositor '
#                                                                      'assigned',
#                                                 'value': 3.0},
#                      'disulfide_bond_count': 16,
#                      'entity_count': 3,
#                      'experimental_method': 'X-ray',
#                      'experimental_method_count': 1,
#                      'inter_mol_covalent_bond_count': 4,
#                      'inter_mol_metalic_bond_count': 0,
#                      'molecular_weight': 110.41,
#                      'na_polymer_entity_types': 'Other',
#                      'nonpolymer_bound_components': ['APA'],
#                      'nonpolymer_entity_count': 1,
#                      'nonpolymer_molecular_weight_maximum': 0.21,
#                      'nonpolymer_molecular_weight_minimum': 0.21,
#                      'polymer_composition': 'homomeric protein',
#                      'polymer_entity_count': 1,
#                      'polymer_entity_count_dna': 0,
#                      'polymer_entity_count_nucleic_acid': 0,
#                      'polymer_entity_count_nucleic_acid_hybrid': 0,
#                      'polymer_entity_count_protein': 1,
#                      'polymer_entity_count_rna': 0,
#                      'polymer_entity_taxonomy_count': 1,
#                      'polymer_molecular_weight_maximum': 27.39,
#                      'polymer_molecular_weight_minimum': 27.39,
#                      'polymer_monomer_count_maximum': 244,
#                      'polymer_monomer_count_minimum': 244,
#                      'resolution_combined': [3.0],
#                      'selected_polymer_entity_types': 'Protein (only)',
#                      'software_programs_combined': ['DENZO',
#                                                     'SCALEPACK',
#                                                     'X-PLOR'],
#                      'solvent_entity_count': 1,
#                      'structure_determination_methodology': 'experimental',
#                      'structure_determination_methodology_priority': 10},
#  'rcsb_id': '1A0L',
#  'rcsb_primary_citation': {'country': 'UK',
#                            'id': 'primary',
#                            'journal_abbrev': 'Nature',
#                            'journal_id_astm': 'NATUAS',
#                            'journal_id_csd': '0006',
#                            'journal_id_issn': '0028-0836',
#                            'journal_volume': '392',
#                            'page_first': '306',
#                            'page_last': '311',
#                            'pdbx_database_id_doi': '10.1038/32703',
#                            'pdbx_database_id_pub_med': 9521329,
#                            'rcsb_authors': ['Pereira, P.J.',
#                                             'Bergner, A.',
#                                             'Macedo-Ribeiro, S.',
#                                             'Huber, R.',
#                                             'Matschiner, G.',
#                                             'Fritz, H.',
#                                             'Sommerhoff, C.P.',
#                                             'Bode, W.'],
#                            'rcsb_journal_abbrev': 'Nature',
#                            'title': 'Human beta-tryptase is a ring-like '
#                                     'tetramer with active sites facing a '
#                                     'central pore.',
#                            'year': 1998},
#  'refine': [{'biso_mean': 28.2,
#              'ls_dres_high': 3.0,
#              'ls_dres_low': 10.0,
#              'ls_number_reflns_obs': 22536,
#              'ls_percent_reflns_obs': 99.3,
#              'ls_percent_reflns_rfree': 5.0,
#              'ls_rfactor_obs': 0.197,
#              'ls_rfactor_rfree': 0.276,
#              'ls_rfactor_rwork': 0.197,
#              'pdbx_data_cutoff_high_abs_f': 10000000000.0,
#              'pdbx_data_cutoff_low_abs_f': 0.0,
#              'pdbx_diffrn_id': ['1'],
#              'pdbx_ls_sigma_f': 2.0,
#              'pdbx_method_to_determine_struct': 'MOLECULAR REPLACEMENT',
#              'pdbx_refine_id': 'X-RAY DIFFRACTION',
#              'pdbx_rfree_selection_details': 'RANDOM'}],
#  'refine_hist': [{'cycle_id': 'LAST',
#                   'd_res_high': 3.0,
#                   'd_res_low': 10.0,
#                   'number_atoms_solvent': 96,
#                   'number_atoms_total': 7872,
#                   'pdbx_number_atoms_ligand': 60,
#                   'pdbx_number_atoms_nucleic_acid': 0,
#                   'pdbx_number_atoms_protein': 7716,
#                   'pdbx_refine_id': 'X-RAY DIFFRACTION'}],
#  'refine_ls_restr': [{'dev_ideal': 0.01,
#                       'pdbx_refine_id': 'X-RAY DIFFRACTION',
#                       'type': 'x_bond_d'},
#                      {'pdbx_refine_id': 'X-RAY DIFFRACTION',
#                       'type': 'x_bond_d_na'},
#                      {'pdbx_refine_id': 'X-RAY DIFFRACTION',
#                       'type': 'x_bond_d_prot'},
#                      {'pdbx_refine_id': 'X-RAY DIFFRACTION',
#                       'type': 'x_angle_d'},
#                      {'pdbx_refine_id': 'X-RAY DIFFRACTION',
#                       'type': 'x_angle_d_na'},
#                      {'pdbx_refine_id': 'X-RAY DIFFRACTION',
#                       'type': 'x_angle_d_prot'},
#                      {'dev_ideal': 2.004,
#                       'pdbx_refine_id': 'X-RAY DIFFRACTION',
#                       'type': 'x_angle_deg'},
#                      {'pdbx_refine_id': 'X-RAY DIFFRACTION',
#                       'type': 'x_angle_deg_na'},
#                      {'pdbx_refine_id': 'X-RAY DIFFRACTION',
#                       'type': 'x_angle_deg_prot'},
#                      {'dev_ideal': 24.69,
#                       'pdbx_refine_id': 'X-RAY DIFFRACTION',
#                       'type': 'x_dihedral_angle_d'},
#                      {'pdbx_refine_id': 'X-RAY DIFFRACTION',
#                       'type': 'x_dihedral_angle_d_na'},
#                      {'pdbx_refine_id': 'X-RAY DIFFRACTION',
#                       'type': 'x_dihedral_angle_d_prot'},
#                      {'dev_ideal': 1.434,
#                       'pdbx_refine_id': 'X-RAY DIFFRACTION',
#                       'type': 'x_improper_angle_d'},
#                      {'pdbx_refine_id': 'X-RAY DIFFRACTION',
#                       'type': 'x_improper_angle_d_na'},
#                      {'pdbx_refine_id': 'X-RAY DIFFRACTION',
#                       'type': 'x_improper_angle_d_prot'},
#                      {'pdbx_refine_id': 'X-RAY DIFFRACTION',
#                       'type': 'x_mcbond_it'},
#                      {'pdbx_refine_id': 'X-RAY DIFFRACTION',
#                       'type': 'x_mcangle_it'},
#                      {'pdbx_refine_id': 'X-RAY DIFFRACTION',
#                       'type': 'x_scbond_it'},
#                      {'pdbx_refine_id': 'X-RAY DIFFRACTION',
#                       'type': 'x_scangle_it'}],
#  'reflns': [{'d_resolution_high': 3.0,
#              'd_resolution_low': 20.0,
#              'pdbx_diffrn_id': ['1'],
#              'pdbx_ordinal': 1,
#              'pdbx_rmerge_iobs': 0.121,
#              'percent_possible_obs': 99.0}],
#  'software': [{'classification': 'data reduction',
#                'name': 'DENZO',
#                'pdbx_ordinal': 1},
#               {'classification': 'data scaling',
#                'name': 'SCALEPACK',
#                'pdbx_ordinal': 2},
#               {'classification': 'model building',
#                'name': 'X-PLOR',
#                'pdbx_ordinal': 3,
#                'version': '3.851'},
#               {'classification': 'refinement',
#                'name': 'X-PLOR',
#                'pdbx_ordinal': 4,
#                'version': '3.851'},
#               {'classification': 'phasing',
#                'name': 'X-PLOR',
#                'pdbx_ordinal': 5,
#                'version': '3.851'}],
#  'struct': {'pdbx_descriptor': 'BETA-TRYPTASE, AMIDO PHENYL PYRUVIC ACID',
#             'title': 'HUMAN BETA-TRYPTASE: A RING-LIKE TETRAMER WITH ACTIVE '
#                      'SITES FACING A CENTRAL PORE'},
#  'struct_keywords': {'pdbx_keywords': 'HYDROLASE/HYDROLASE INHIBITOR',
#                      'text': 'TRYPSIN-LIKE SERINE PROTEINASE, TETRAMER, '
#                              'HEPARIN, ALLERGY, ASTHMA, SERINE PROTEINASE, '
#                              'HYDROLASE-HYDROLASE INHIBITOR complex'},
#  'symmetry': {'int_tables_number': 76, 'space_group_name_hm': 'P 41'}}

# %%
from pdbx.reader.PdbxReader import PdbxReader
from pdbx.reader.PdbxContainers import *

# %%
# AF-P07604-F1-model_v3.pdb
ifh = open("../data/alpha/AF-P07604-F1-model_v3.pdb")
pRd = PdbxReader(ifh)

# %%
data = []
pRd.read(data)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/pdbx/reader/PdbxReader.py:360, in PdbxReader.__tokenizer(self, ifh)
#     359 while True:
# --> 360     line = next(fileIter)
#     361     self.__curLineNumber += 1
#
# StopIteration:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Input In [30], in <cell line: 2>()
#       1 data = []
# ----> 2 pRd.read(data)
#
# File ~/anaconda3/lib/python3.9/site-packages/pdbx/reader/PdbxReader.py:72, in PdbxReader.read(self, containerList)
#      70 self.__curLineNumber = 0
#      71 try:
# ---> 72     self.__parser(self.__tokenizer(self.__ifh), containerList)
#      73 except StopIteration:
#      74     pass
#
# File ~/anaconda3/lib/python3.9/site-packages/pdbx/reader/PdbxReader.py:132, in PdbxReader.__parser(self, tokenizer, containerList)
#     129 # Find the first reserved word and begin capturing data.
#     130 #
#     131 while True:
# --> 132     curCatName, curAttName, curQuotedString, curWord = next(tokenizer)
#     133     if curWord is None:
#     134         continue
#
# RuntimeError: generator raised StopIteration

# %%
block = data[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 block = data[0]
#
# IndexError: list index out of range
